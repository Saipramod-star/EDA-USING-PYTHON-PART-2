# %%
import numpy as np
import pandas as pd
import seaborn as sn

# %%
data = pd.read_csv(r'C:/Users/SAI RAM/Desktop/ML things/Data Files/2. ST Academy - Classification models resource files/House-Price.csv')

# %%
data
# Out:
#      price  resid_area  air_qual  room_num   age  dist1  dist2  dist3  dist4  \
# 0     24.0       32.31     0.538     6.575  65.2   4.35   3.81   4.18   4.01
# 1     21.6       37.07     0.469     6.421  78.9   4.99   4.70   5.12   5.06
# 2     34.7       37.07     0.469     7.185  61.1   5.03   4.86   5.01   4.97
# 3     33.4       32.18     0.458     6.998  45.8   6.21   5.93   6.16   5.96
# 4     36.2       32.18     0.458     7.147  54.2   6.16   5.86   6.37   5.86
# ..     ...         ...       ...       ...   ...    ...    ...    ...    ...
# 501   22.4       41.93     0.573     6.593  69.1   2.64   2.45   2.76   2.06
# 502   20.6       41.93     0.573     6.120  76.7   2.44   2.11   2.46   2.14
# 503   23.9       41.93     0.573     6.976  91.0   2.34   2.06   2.29   1.98
# 504   22.0       41.93     0.573     6.794  89.3   2.54   2.31   2.40   2.31
# 505   19.0       41.93     0.573     6.030  80.8   2.72   2.24   2.64   2.42
#
# ...

# %% [markdown]
# #### returns the first 5 rows and columns

# %%
data.head()
# Out:
#    price  resid_area  air_qual  room_num   age  dist1  dist2  dist3  dist4  \
# 0   24.0       32.31     0.538     6.575  65.2   4.35   3.81   4.18   4.01
# 1   21.6       37.07     0.469     6.421  78.9   4.99   4.70   5.12   5.06
# 2   34.7       37.07     0.469     7.185  61.1   5.03   4.86   5.01   4.97
# 3   33.4       32.18     0.458     6.998  45.8   6.21   5.93   6.16   5.96
# 4   36.2       32.18     0.458     7.147  54.2   6.16   5.86   6.37   5.86
#
#    teachers  poor_prop airport  n_hos_beds  n_hot_rooms waterbody  rainfall  \
# 0      24.7       4.98     YES       5.480      11.1920     River        23
# 1      22.2       9.14      NO       7.332      12.1728      Lake        42
# 2      22.2       4.03      NO       7.394     101.1200      None        38
# 3      21.3       2.94     YES       9.268      11.2672      Lake        45
# 4      21.3       5.33      NO       8.824      11.2896      Lake        55
#
#   bus_ter     parks  Sold
# 0     YES  0.049347     0
# ...

# %% [markdown]
# #### returns the last 5 rows and columns of the data

# %%
data.tail()
# Out:
#      price  resid_area  air_qual  room_num   age  dist1  dist2  dist3  dist4  \
# 501   22.4       41.93     0.573     6.593  69.1   2.64   2.45   2.76   2.06
# 502   20.6       41.93     0.573     6.120  76.7   2.44   2.11   2.46   2.14
# 503   23.9       41.93     0.573     6.976  91.0   2.34   2.06   2.29   1.98
# 504   22.0       41.93     0.573     6.794  89.3   2.54   2.31   2.40   2.31
# 505   19.0       41.93     0.573     6.030  80.8   2.72   2.24   2.64   2.42
#
#      teachers  poor_prop airport  n_hos_beds  n_hot_rooms       waterbody  \
# 501      19.0       9.67      NO       9.348      12.1792  Lake and River
# 502      19.0       9.08     YES       6.612      13.1648  Lake and River
# 503      19.0       5.64      NO       5.478      12.1912            None
# 504      19.0       6.48     YES       7.940      15.1760            None
# 505      19.0       7.88     YES      10.280      10.1520            None
#
#      rainfall bus_ter     parks  Sold
# ...

# %% [markdown]
# #### return the shape of the data

# %%
data.shape
# Out:
# (506, 19)

# %% [markdown]
# #### returns the column names of the data

# %%
data.columns
# Out:
# Index(['price', 'resid_area', 'air_qual', 'room_num', 'age', 'dist1', 'dist2',
#        'dist3', 'dist4', 'teachers', 'poor_prop', 'airport', 'n_hos_beds',
#        'n_hot_rooms', 'waterbody', 'rainfall', 'bus_ter', 'parks', 'Sold'],
#       dtype='object')

# %% [markdown]
# #### returns the unique values for every column

# %%
data.nunique()
# Out:
# price          228
# resid_area      76
# air_qual        81
# room_num       446
# age            356
# dist1          339
# dist2          354
# dist3          339
# dist4          353
# teachers        46
# poor_prop      455
# airport          2
# n_hos_beds     454
# n_hot_rooms    423
# waterbody        4
# rainfall        42
# bus_ter          1
# parks          506
# Sold             2
# dtype: int64

# %% [markdown]
# #### returns the unique values of the named column

# %%
data['Sold'].unique()
# Out:
# array([0, 1], dtype=int64)

# %% [markdown]
# ## Cleaning the data set

# %% [markdown]
# #### returns the sum of the null values of  all columns

# %%
data.isnull().sum()
# Out:
# price          0
# resid_area     0
# air_qual       0
# room_num       0
# age            0
# dist1          0
# dist2          0
# dist3          0
# dist4          0
# teachers       0
# poor_prop      0
# airport        0
# n_hos_beds     8
# n_hot_rooms    0
# waterbody      0
# rainfall       0
# bus_ter        0
# parks          0
# Sold           0
# dtype: int64

# %% [markdown]
# ##      Relationship analysis

# %% [markdown]
# ### Correlation matrix : returns the relation shiop between all the numerical columns

# %%
data_corr = data.corr()

# %%
sn.heatmap(data_corr, xticklabels = data_corr.columns, yticklabels = data_corr.columns, annot = True)

# %% [markdown]
# ### Pair plot: It gives the relationship between every 2 columns in the whole data set

# %%
sn.pairplot(data)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\numpy\lib\histograms.py:824: RuntimeWarning: invalid value encountered in greater_equal
#   keep = (tmp_a >= first_edge)
# C:\ProgramData\Anaconda3\lib\site-packages\numpy\lib\histograms.py:825: RuntimeWarning: invalid value encountered in less_equal
#   keep &= (tmp_a <= last_edge)

# %% [markdown]
# ### Scatter plot

# %%
sn.relplot(x = 'price', y = 'room_num', hue = 'Sold', data = data)

# %% [markdown]
# ### Histogram

# %%
sn.distplot(data['price'],bins  =8)       # bins represents the no of occurances of the specified column
